# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import seaborn as sns
import numpy as np
pd.set_option('display.max_columns', 500)

df = pd.read_csv('./data/hwinfo.csv', encoding = "ISO-8859-1")

df.head()
# Out:
#         Date     Time  VirtualMemoryCommited  VirtualMemoryAvailable  \
# 0  29.1.2019  13:07.8                  11937                   63246
# 1  29.1.2019  13:09.9                  11996                   63187
# 2  29.1.2019  13:11.9                  12218                   62964
# 3  29.1.2019  13:14.0                  12299                   62884
# 4  29.1.2019  13:16.1                  12383                   62800
#
#    VirtualMemoryLoad  PhysicalMemoryUsed  PhysicalMemoryAvailable  \
# 0               15.8                8863                    56592
# 1               15.9                8874                    56581
# 2               16.2                8981                    56474
# 3               16.3                9090                    56365
# 4               16.4                9251                    56203
#
#    PhysicalMemoryLoad  PageFileUsage  Core0VID  Core1VID  Core2VID  Core3VID  \
# ...

# %%
df.info(all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 187 columns):
# Date                                                       object
# Time                                                       object
# VirtualMemoryCommited                                      int64
# VirtualMemoryAvailable                                     int64
# VirtualMemoryLoad                                          float64
# PhysicalMemoryUsed                                         int64
# PhysicalMemoryAvailable                                    int64
# PhysicalMemoryLoad                                         float64
# PageFileUsage                                              int64
# Core0VID                                                   float64
# Core1VID                                                   float64
# Core2VID                                                   float64
# Core3VID                                                   float64
# ...

# %%
df['period'] = df['Date'].astype(str) + " " + df['Time'].astype(str)

# %%
df.info(all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 188 columns):
# Date                                                       object
# Time                                                       object
# VirtualMemoryCommited                                      int64
# VirtualMemoryAvailable                                     int64
# VirtualMemoryLoad                                          float64
# PhysicalMemoryUsed                                         int64
# PhysicalMemoryAvailable                                    int64
# PhysicalMemoryLoad                                         float64
# PageFileUsage                                              int64
# Core0VID                                                   float64
# Core1VID                                                   float64
# Core2VID                                                   float64
# Core3VID                                                   float64
# ...

# %%
df.period
# Out:
# 0      29.1.2019 13:07.8
# 1      29.1.2019 13:09.9
# 2      29.1.2019 13:11.9
# 3      29.1.2019 13:14.0
# 4      29.1.2019 13:16.1
# 5      29.1.2019 13:18.2
# 6      29.1.2019 13:20.4
# 7      29.1.2019 13:22.4
# 8      29.1.2019 13:24.5
# 9      29.1.2019 13:26.6
# 10     29.1.2019 13:28.6
# 11     29.1.2019 13:30.7
# 12     29.1.2019 13:32.8
# 13     29.1.2019 13:34.9
# 14     29.1.2019 13:37.0
# 15     29.1.2019 13:39.0
# 16     29.1.2019 13:41.1
# 17     29.1.2019 13:43.1
# 18     29.1.2019 13:45.2
# 19     29.1.2019 13:47.2
# 20     29.1.2019 13:49.3
# 21     29.1.2019 13:51.3
# 22     29.1.2019 13:53.4
# 23     29.1.2019 13:55.4
# 24     29.1.2019 13:57.5
# 25     29.1.2019 13:59.5
# 26     29.1.2019 14:01.6
# 27     29.1.2019 14:03.6
# 28     29.1.2019 14:05.8
# 29     29.1.2019 14:07.9
#              ...
# 260    29.1.2019 22:13.3
# 261    29.1.2019 22:15.4
# 262    29.1.2019 22:17.4
# 263    29.1.2019 22:19.5
# 264    29.1.2019 22:21.6
# 265    29.1.2019 22:23.6
# ...

# %%
df["period"] = pd.to_datetime(df["period"])

# %%
df.info(all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 188 columns):
# Date                                                       object
# Time                                                       object
# VirtualMemoryCommited                                      int64
# VirtualMemoryAvailable                                     int64
# VirtualMemoryLoad                                          float64
# PhysicalMemoryUsed                                         int64
# PhysicalMemoryAvailable                                    int64
# PhysicalMemoryLoad                                         float64
# PageFileUsage                                              int64
# Core0VID                                                   float64
# Core1VID                                                   float64
# Core2VID                                                   float64
# Core3VID                                                   float64
# ...

# %%
import seaborn as sns
sns.relplot(x="Time",y="TotalCPUUsage",kind="line",data=df)

# %%
sns.relplot(x="Time",y1="TotalCPUUsage", y2="CPUPackage",kind="line",data=df)
